# %% [markdown]
# # Explorando um PEQUENO conjunto de dados do Enem 2018

# %% [markdown]
# ### Carregando os dados do arquivo csv

# %%
# importa a biblioteca pandas
import pandas as pd

# %% [markdown]
# ### Observação
# Arquivos carregados (Upload) para o Google Colab serão excluídos após término da máquina virtual.

# %%
## arquivo externo ao Google Colab
arquivo = "https://github.com/cesaralberto91/google-colab/blob/master/amostra-enem-2018.csv?raw=true"

## arquivo do Google Colab
#arquivo = 'sample_data/california_housing_test.csv'

## arquivo do Google Drive
## é necessário montar o drive
#arquivo = "drive/My Drive/encompif_2020/dataset.txt"

# %%
# carrega os dados do arquivo csv em um data frame
dados = pd.read_csv(arquivo, delimiter=",")

# exibe as 5 primeiras linhas
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q025  Q026 Q027
# 0  180009327796    2018                  2112209  ...    B     A    A
# 1  180012890374    2018                  3557105  ...    B     D    D
# 2  180008223824    2018                  2506301  ...    B     A    E
# 3  180007859645    2018                  3534807  ...    A     B    A
# 4  180013499517    2018                  3523107  ...    B     A    A
#
# [5 rows x 137 columns]

# %%
## exibe as colunas do data frame
dados.columns
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        ...
#        'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025', 'Q026',
#        'Q027'],
#       dtype='object', length=137)

# %%
## exibe os valores sem repetir (valores únicos)
dados['SG_UF_RESIDENCIA'].unique()
# Out:
# array(['MA', 'SP', 'PB', 'PE', 'AL', 'BA', 'MS', 'PI', 'RS', 'RN', 'ES',
#        'MG', 'SE', 'AM', 'AP', 'RO', 'CE', 'GO', 'PA', 'RJ', 'SC', 'MT',
#        'PR', 'TO', 'DF', 'AC', 'RR'], dtype=object)

# %%
## exibe a quantidade de inscrições por estado
dados['SG_UF_RESIDENCIA'].value_counts()
# Out:
# SP    23299
# MG    14615
# BA    10199
# RJ     9583
# CE     8255
# PE     7571
# PA     7007
# RS     6177
# PR     5821
# MA     5441
# GO     4822
# PB     3846
# SC     3102
# RN     3088
# AM     3085
# PI     2910
# ES     2786
# DF     2618
# MT     2447
# AL     2213
# MS     1889
# SE     1849
# RO     1554
# TO     1354
# AC      996
# AP      957
# RR      360
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
## dados normalizados
dados['SG_UF_RESIDENCIA'].value_counts(normalize=True)
# Out:
# SP   0.17
# MG   0.11
# BA   0.07
# RJ   0.07
# CE   0.06
# PE   0.05
# PA   0.05
# RS   0.04
# PR   0.04
# MA   0.04
# GO   0.03
# PB   0.03
# SC   0.02
# RN   0.02
# AM   0.02
# PI   0.02
# ES   0.02
# DF   0.02
# MT   0.02
# AL   0.02
# MS   0.01
# SE   0.01
# RO   0.01
# TO   0.01
# AC   0.01
# AP   0.01
# RR   0.00
# Name: SG_UF_RESIDENCIA, dtype: float64

# %%
## Idade da pessoa mais nova
dados['NU_IDADE'].min()

## Idade da pessoa mais velha
#dados['NU_IDADE'].max()

## Idade média dos inscritos
dados['NU_IDADE'].mean()

## Quantidade, média, desvio padrão, mínimo, máximo, ...
dados['NU_IDADE'].describe()
# Out:
# count   137,843.00
# mean         22.38
# std           7.61
# min          13.00
# 25%          18.00
# 50%          19.00
# 75%          24.00
# max          78.00
# Name: NU_IDADE, dtype: float64

# %%
## 
#dados['NU_IDADE'].plot(kind='hist')
dados['NU_IDADE'].hist()

# %%
## ordena o data frame pela idade e exibe os 5 primeiros registros
dados.sort_values('NU_IDADE', ascending=False).head()
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q025  Q026 Q027
# 10907   180013160905    2018                  3304557  ...    B     A    A
# 25851   180012973345    2018                  5002704  ...    A     A    A
# 59601   180013377786    2018                  3522109  ...    A     B    A
# 102779  180013364484    2018                  2507507  ...    B     A    F
# 10723   180013233605    2018                  3302502  ...    B     A    B
#
# [5 rows x 137 columns]

# %%
## exibe 10 registros aleatoriamente, pode ser útil para gerar uma amostra menor dos dados
dados.sort_values('NU_IDADE', ascending=False).sample(10)
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q025  Q026 Q027
# 116897  180009447416    2018                  3552809  ...    B     A    C
# 104139  180010872890    2018                  3516200  ...    B     A    A
# 8240    180010063097    2018                  3137304  ...    A     A    A
# 29059   180011992339    2018                  3550308  ...    B     A    A
# 120011  180011664383    2018                  2304400  ...    B     A    A
# 81492   180009284468    2018                  2909802  ...    B     B    A
# 39599   180011300700    2018                  1500107  ...    A     A    A
# 36175   180011196450    2018                  2111300  ...    A     B    A
# 83539   180008375840    2018                  3304557  ...    B     B    A
# 130018  180011344601    2018                  5300108  ...    B     A    A
#
# [10 rows x 137 columns]

# %%
## exibir somente as inscrições do estado de SP
dados.query("SG_UF_RESIDENCIA == 'SP'")

## exibir as pessoas que obtiveram nota em ciências naturais maior que 800
#dados.query("NU_NOTA_CN > 800")

## exibir somente as inscrições dos estados de SP e PR
#dados.query("SG_UF_RESIDENCIA in ['MG', 'PR']")
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q025  Q026 Q027
# 14043   180008393676    2018                  2408003  ...    B     A    D
# 33520   180013809317    2018                  2408102  ...    B     A    D
# 96734   180009979706    2018                  2800308  ...    B     B    D
# 96872   180007342497    2018                  5300108  ...    B     B    D
# 106298  180009960152    2018                  3525904  ...    B     A    D
# 132198  180011926158    2018                  3106200  ...    B     A    D
# 137470  180010189296    2018                  2918407  ...    B     A    B
#
# [7 rows x 137 columns]

# %%
## exibe a médias das notas de ciências naturais por estado e ordena o resultado
media_CN_por_estado = dados.groupby("SG_UF_RESIDENCIA").mean()['NU_NOTA_CN'].sort_values(ascending=False)
media_CN_por_estado
# Out:
# SG_UF_RESIDENCIA
# SP    511.556389
# MG    508.770028
# PR    506.527430
# SC    506.221953
# DF    505.662825
# RJ    504.151817
# ES    501.555539
# RS    500.582938
# GO    494.343541
# MS    492.421845
# RN    489.796790
# SE    486.285415
# MT    483.050817
# PE    482.644201
# CE    482.089328
# PB    481.981545
# BA    481.542953
# RR    479.622407
# AL    477.430684
# PA    475.233670
# PI    474.516741
# RO    474.230545
# TO    474.085122
# AP    471.813208
# AM    471.770047
# MA    470.465733
# AC    464.716598
# Name: NU_NOTA_CN, dtype: float64

# %%
## importa a biblioteca pyplot (gráfico)
import matplotlib.pyplot as plt

# %%
## exibe gráfico de pizza
media_CN_por_estado.plot(
    kind='pie',
    title='Média de Ciências Naturais por Estado',
    figsize=(8,8))

plt.show()

# %% [markdown]
# Gráfico de pizza normalmente não é muito bom porque é difícil comparar a área entre dois 'pedaços da pizza'.
#
#
# ---

# %%
## exibe gráfico de pizza
media_CN_por_estado.plot(
    kind='bar',
    title='Média das notas de Ciências Naturais por Estado',
    x="Estados",
    figsize=(12, 4))

plt.ylabel("Médias das notas")
plt.xlabel("Estados")
plt.savefig("media-notas-ciencias-naturais-por-estado.png", dpi=300)
#plt.show()

# %%
## import da biblioteca Seaborn para trabalhar com gráficos
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
## define o tamanho do gráfico (tamanho eixo x, tamanho eixo y)
plt.figure(figsize=(12,4))

## exibe linhas horizontais referente aos valores do eixo y - configuração global
sns.set_style("whitegrid")

## cria o gráfico de barras
sns.barplot(x=media_CN_por_estado.index,
            y=media_CN_por_estado.values,
            
            palette=sns.color_palette('BuGn_r', n_colors=len(media_CN_por_estado)))

## exibe o gráfico de barras
plt.plot()
# Out:
# []

# %%
## descreve SOMENTE as colunas numéricas porque irá calcular a média, mediana, desvio padrão, etc.
dados.describe()
# Out:
#        NU_INSCRICAO    NU_ANO  ...  NU_NOTA_REDACAO           Q005
# count  1.378440e+05  137844.0  ...    103774.000000  137844.000000
# mean   1.800104e+11    2018.0  ...       509.133116       3.895447
# std    1.918950e+06       0.0  ...       187.014052       1.505254
# min    1.800072e+11    2018.0  ...         0.000000       1.000000
# 25%    1.800088e+11    2018.0  ...       360.000000       3.000000
# 50%    1.800104e+11    2018.0  ...       520.000000       4.000000
# 75%    1.800120e+11    2018.0  ...       620.000000       5.000000
# max    1.800140e+11    2018.0  ...      1000.000000      20.000000
#
# [8 rows x 94 columns]

# %%
## define o formato para exibir valores decimais com duas casas
# %precision %.2f
pd.options.display.float_format = '{:,.2f}'.format

# %%
## descreve os dados novamente formatado com duas casas decimais
dados.describe()
# Out:
#             NU_INSCRICAO     NU_ANO  ...  NU_NOTA_REDACAO       Q005
# count         137,844.00 137,844.00  ...       103,774.00 137,844.00
# mean  180,010,423,553.31   2,018.00  ...           509.13       3.90
# std         1,918,950.00       0.00  ...           187.01       1.51
# min   180,007,186,686.00   2,018.00  ...             0.00       1.00
# 25%   180,008,761,760.75   2,018.00  ...           360.00       3.00
# 50%   180,010,373,993.50   2,018.00  ...           520.00       4.00
# 75%   180,012,032,768.50   2,018.00  ...           620.00       5.00
# max   180,014,002,596.00   2,018.00  ...         1,000.00      20.00
#
# [8 rows x 94 columns]

# %%
## cria um vetor com os nomes das colunas
colunas_de_notas = ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']

## cria um data frame somente com as colunas selecionadas e exclui as linhas sem valores (nan)
dados_notas = dados[colunas_de_notas].dropna()

## exibe os 5 primeiros registros
dados_notas.head()
# Out:
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# 1      523.10      671.30      661.60      738.00           680.00
# 2      409.20      531.70      389.00      438.10           600.00
# 3      452.30      505.50      448.50      544.90           400.00
# 6      428.50      505.20      521.00      436.80           560.00
# 8      491.80      575.70      524.40      487.60           660.00

# %%
## altera os nomes das colunas (series) do data frame
dados_notas.columns = ['ciencias_naturais', 'ciencias_humanas', 'linguagem_codigo', 'matematica', 'redacao']

## exibe os 10 primeiros registros (linhas)
dados_notas.head(10)
# Out:
#     ciencias_naturais  ciencias_humanas  linguagem_codigo  matematica  redacao
# 1              523.10            671.30            661.60      738.00   680.00
# 2              409.20            531.70            389.00      438.10   600.00
# 3              452.30            505.50            448.50      544.90   400.00
# 6              428.50            505.20            521.00      436.80   560.00
# 8              491.80            575.70            524.40      487.60   660.00
# 9              568.00            650.50            633.10      587.60   520.00
# 10             630.20            651.50            625.90      767.50   800.00
# 11             591.40            622.30            614.90      584.10   680.00
# 12             414.20            626.30            486.30      474.70   300.00
# 13             487.50            607.00            594.00      559.70   360.00

# %%
## exibe a quantidade de registros (linhas) do data frame
len(dados_notas)
# Out:
# 97270

# %%
plt.figure(figsize=(8,4))

## cria o gráfico boxplot das notas
sns.boxplot(data=dados_notas)

## rotaciona os labels (ticks) do eixo x
plt.xticks(rotation=45)
plt.plot()
# Out:
# []

# %%
## exibe a correlação entre as colunas (series) do data frame
dados_notas.corr()
# Out:
#                  NU_NOTA_CN  NU_NOTA_CH  ...  NU_NOTA_MT  NU_NOTA_REDACAO
# NU_NOTA_CN             1.00        0.57  ...        0.58             0.51
# NU_NOTA_CH             0.57        1.00  ...        0.53             0.50
# NU_NOTA_LC             0.60        0.70  ...        0.57             0.56
# NU_NOTA_MT             0.58        0.53  ...        1.00             0.48
# NU_NOTA_REDACAO        0.51        0.50  ...        0.48             1.00
#
# [5 rows x 5 columns]

# %%
## gera o gráfico pairplot
sns.pairplot(dados_notas)
